# %%
# Import library python
import pandas as pd # Untuk manipulasi dan analisis data
import numpy as np # Untuk komputasi numerik
import matplotlib.pyplot as plt # Untuk visualisasi data
import seaborn as sns # Untuk visualisasi data yang lebih estetis

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1'],
                    'B': ['B0', 'B1']},
                   index=[0, 1])
df1
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1

# %%
df2 = pd.DataFrame({'A': ['A2', 'A3'],
                    'B': ['B2', 'B3']},
                   index=[2, 3])
df2
# Out:
#     A   B
# 2  A2  B2
# 3  A3  B3

# %%
df3 = pd.DataFrame({'A': ['A4', 'A5'],
                    'B': ['B4', 'B5']},
                   index=[4, 5])
df3
# Out:
#     A   B
# 4  A4  B4
# 5  A5  B5

# %%
pd.concat([df1,df2,df3])
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 4  A4  B4
# 5  A5  B5

# %%
rekap_sales = pd.DataFrame(
    {
        'id' : [123,123,134,134,134,211,211,243,243,243,243,310],
        'bulan' : [1,2,1,2,3,2,3,1,2,3,4,3],
        'n_items' :[10,20,20,15,13,9,7,10,5,10,10,20],
        'n_sales' : [100,200,250,150,130,90,70,100,50,150,100,200]
    }
)

karyawan = pd.DataFrame(
    {
        'id' :  [101,123,134,138,201,210,211,240,243,310],
        'nama' : ['James', 'Mary', 'Michael', 'Patricia', 'Robert', 'Jennifer', 'John', 'Linda', 'David', 'Elizabeth'],
    }
)

# %%
# Menghubungkan colab dengan google drive
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
# Membaca atau menghubungkan direktori folder dataset yang ada di google drive
path = "/content/gdrive/MyDrive/Datasets/DS/data/"

# %%
# Membaca dan menampilkan file
df = pd.read_csv(path + 'dirtydata.csv')

# %%
df
# Out:
#           ID           Nama Pegawai Tempat Lahir Tanggal Lahir Jenis Kelamin  \
# 0   10010104   Nugroho Aldi Saputra      Jakarta    11-06-1982          Pria
# 1   10010106           Henry Rosyid      Jakarta    13-07-1971             L
# 2   10010107           Misna Oktina      Jakarta    14-04-1971           NaN
# 3   10010119          Reza Maryanto     Sukabumi    31-01-1981             L
# 4   10010108           Lukman Hakim   Majalengka    14-07-1988             L
# 5   10010109     Dwi Primardiansyah   Pekalongan    15-05-1983             L
# 6   10010107           Misna Oktina      Jakarta    14-04-1971        Wanita
# 7   10010111      Bachtiar Hermawan      Jakarta    23-06-1963     Laki-Laki
# 8   10010112           Luthfiansyah   Majalengka    24-08-1989             L
# 9   10010120      Zaki Adityawijaya      Jakarta    31-08-1987             L
# 10  10010110          Ahmad Firdaus   Pekalongan    17-08-1980             L
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   21 non-null     int64
#  1   Nama Pegawai         21 non-null     object
#  2   Tempat Lahir         21 non-null     object
#  3   Tanggal Lahir        21 non-null     object
#  4   Jenis Kelamin        20 non-null     object
#  5   Kota Tempat Tinggal  20 non-null     object
#  6   No HP                15 non-null     float64
#  7   Jam Kerja            20 non-null     object
#  8   Berat                21 non-null     object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 1.6+ KB

# %%
df.describe()
# Out:
#                  ID         No HP
# count  2.100000e+01  1.500000e+01
# mean   1.001011e+07  8.376593e+10
# std    5.816643e+00  3.319794e+09
# min    1.001010e+07  8.121111e+10
# 25%    1.001011e+07  8.124445e+10
# 50%    1.001011e+07  8.151112e+10
# 75%    1.001012e+07  8.572223e+10
# max    1.001012e+07  8.991111e+10

# %%
df.isnull().sum()
# Out:
# ID                     0
# Nama Pegawai           0
# Tempat Lahir           0
# Tanggal Lahir          0
# Jenis Kelamin          1
# Kota Tempat Tinggal    1
# No HP                  6
# Jam Kerja              1
# Berat                  0
# dtype: int64

# %%
pd.to_datetime(df['Tanggal Lahir'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-93b335f36aec> in <cell line: 0>()
# ----> 1 pd.to_datetime(df['Tanggal Lahir'])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065             result = arg.map(cache_array)
#    1066         else:
# -> 1067             values = convert_listlike(arg._values, format)
#    1068             result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
# ...

# %%
df['Tanggal Lahir'].apply(pd.to_datetime)
# Out:
# <ipython-input-44-f5cb73bcef90>:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Tanggal Lahir'].apply(pd.to_datetime)
# 0    1982-11-06
# 1    1971-07-13
# 2    1971-04-14
# 3    1981-01-31
# 4    1988-07-14
# 5    1983-05-15
# 6    1971-04-14
# 7    1963-06-23
# 8    1989-08-24
# 9    1987-08-31
# 10   1980-08-17
# 11   1983-07-29
# 12   1972-06-11
# 13   1980-05-25
# 14   1987-12-03
# 15   1977-12-27
# 16   1971-01-01
# 17   1959-01-09
# 18   1965-09-26
# 19   1988-05-29
# 20   1989-08-30
# Name: Tanggal Lahir, dtype: datetime64[ns]

# %%
df.loc[0, "Tanggal Lahir"].month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-7d61118153d5> in <cell line: 0>()
# ----> 1 df.loc[0, "Tanggal Lahir"].month
#
# AttributeError: 'str' object has no attribute 'month'

# %%
pd.to_datetime(..., format = "%d/%m/%y")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-47-f5ded62c3142> in <cell line: 0>()
# ----> 1 pd.to_datetime(0, "Tanggal Lahir", format = "%d/%m/%y")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1099             result = convert_listlike(argc, format)
#    1100     else:
# -> 1101         result = convert_listlike(np.array([arg]), format)[0]
#    1102         if isinstance(arg, bool) and isinstance(result, np.bool_):
#    1103             result = bool(result)  # TODO: avoid this kludge.
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
# ...
